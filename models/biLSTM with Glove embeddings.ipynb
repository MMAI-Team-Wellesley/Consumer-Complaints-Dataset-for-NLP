# %%
# Load packages
import numpy as np
import pandas as pd
from google.colab import files
import re
from nltk.corpus import stopwords
from nltk import word_tokenize
from bs4 import BeautifulSoup
from sklearn.model_selection import train_test_split
from gensim.models import Word2Vec, KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec
import tensorflow as tf
from tensorflow.keras.layers import Dense, Embedding, GRU, SpatialDropout1D, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Import the cleaned dataset with the glove embeddings
df = pd.read_csv('/content/customer_complaints_clean_vF.csv')
df.head()
# Out:
#             product                                          narrative
# 0       credit_card  purchase order day shipping amount receive pro...
# 1       credit_card  forwarded message date tue subject please inve...
# 2    retail_banking  forwarded message cc sent friday pdt subject f...
# 3  credit_reporting  payment history missing credit report speciali...
# 4  credit_reporting  payment history missing credit report made mis...

# %%
import urllib.request

url = 'https://nlp.stanford.edu/data/glove.6B.zip'
urllib.request.urlretrieve(url, 'glove.6B.zip')
# Out:
# ('glove.6B.zip', <http.client.HTTPMessage at 0x7f2e49005490>)

# %%
import zipfile

with zipfile.ZipFile('glove.6B.zip', 'r') as zip_ref:
    zip_ref.extractall('glove')

# %%
def load_embedding(filename):
    with open(filename, 'r', encoding='utf-8') as f:
        lines = f.readlines()[1:]
        embedding_dict = {}
        for line in lines:
            values = line.split()
            word = values[0]
            coefs = np.asarray(values[1:], dtype='float32')
            embedding_dict[word] = coefs
    return embedding_dict

# %%
embedding_dict = load_embedding('glove/glove.6B.100d.txt')

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Separate target and input data
X = df['narrative'].astype(str).tolist()
Y = df['product'].astype(str).tolist()

# %%
print(df.dtypes)
# Out:
# product      object
# narrative    object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
# Convert target labels to numerical labels
label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(Y)
from keras.utils import to_categorical

# Convert target data to one-hot encoded vectors
Y = to_categorical(Y, num_classes=5)

# Remove extra dimension from Y
Y = Y.reshape(-1, 5)

# %%
Y.shape
# Out:
# (86111, 5)

# %%
# Convert X to list of strings
X_str = [str(sentence) for sentence in X]

# Tokenize input data
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(X_str)
X = tokenizer.texts_to_sequences(X_str)
X = pad_sequences(X, maxlen=200)

# %%
# Create embedding matrix for input vocabulary
word_index = tokenizer.word_index
embedding_matrix = np.zeros((len(word_index) + 1, 100))
for word, i in word_index.items():
    embedding_vector = embedding_dict.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
# Split data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.utils.class_weight import compute_class_weight

# Convert one-hot encoded labels to class labels
Y_train_labels = np.argmax(Y_train, axis=1)

# Compute class weights
class_weights = compute_class_weight('balanced', classes=np.unique(Y_train_labels), y=Y_train_labels)

# Convert class weights to dictionary
class_weights_dict = dict(enumerate(class_weights))

# %%
#Y = np.squeeze(Y)

# %%
# Define the number of words to consider
num_words = 5000
maxlen = max([len(seq) for seq in X])

# %%
# Build biLSTM model
from keras.layers import Bidirectional, LSTM
from keras.models import Sequential

model = Sequential()
model.add(Embedding(input_dim=num_words, output_dim=32, input_length=maxlen))
model.add(Bidirectional(LSTM(units=64)))
model.add(Dense(5, activation='softmax'))


model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, epochs=10, batch_size=128, validation_split=0.2, class_weight=class_weights_dict, callbacks=[EarlyStopping(monitor='val_loss', patience=3, min_delta=0.0001)])
# Out:
# Epoch 1/10
# 431/431 [==============================] - 274s 626ms/step - loss: 1.0400 - accuracy: 0.5781 - val_loss: 1.3379 - val_accuracy: 0.3309
# Epoch 2/10
# 431/431 [==============================] - 264s 614ms/step - loss: 0.9215 - accuracy: 0.6324 - val_loss: 0.7925 - val_accuracy: 0.7006
# Epoch 3/10
# 431/431 [==============================] - 265s 615ms/step - loss: 0.6526 - accuracy: 0.7702 - val_loss: 0.6141 - val_accuracy: 0.7931
# Epoch 4/10
# 431/431 [==============================] - 268s 622ms/step - loss: 0.5657 - accuracy: 0.8054 - val_loss: 0.6287 - val_accuracy: 0.7872
# Epoch 5/10
# 431/431 [==============================] - 266s 617ms/step - loss: 0.5457 - accuracy: 0.8128 - val_loss: 0.5784 - val_accuracy: 0.8117
# Epoch 6/10
# 431/431 [==============================] - 269s 625ms/step - loss: 0.5290 - accuracy: 0.8181 - val_loss: 0.7965 - val_accuracy: 0.7220
# Epoch 7/10
# 431/431 [==============================] - 266s 617ms/step - loss: 0.5553 - accuracy: 0.8025 - val_loss: 0.6317 - val_accuracy: 0.7815
# Epoch 8/10
# 431/431 [==============================] - 268s 622ms/step - loss: 0.4662 - accuracy: 0.8333 - val_loss: 0.5601 - val_accuracy: 0.8151
# Epoch 9/10
# 431/431 [==============================] - 267s 621ms/step - loss: 0.4517 - accuracy: 0.8401 - val_loss: 0.6206 - val_accuracy: 0.7966
# Epoch 10/10
# 431/431 [==============================] - 265s 614ms/step - loss: 0.4025 - accuracy: 0.8541 - val_loss: 0.5387 - val_accuracy: 0.8199

# %%
scores = model.evaluate(X_test, Y_test)
print(f"Test Loss: {scores[0]:.4f}")
print(f"Test Accuracy: {scores[1]*100:.2f}%")
# Out:
# 539/539 [==============================] - 31s 57ms/step - loss: 0.5363 - accuracy: 0.8206
# Test Loss: 0.5363
# Test Accuracy: 82.06%

# %%
Y_test = np.argmax(Y_test, axis=1)
Y_pred = model.predict(X_test)
Y_pred = np.argmax(Y_pred, axis=1)
print(classification_report(Y_test, Y_pred))
# Out:
# 539/539 [==============================] - 32s 57ms/step
#               precision    recall  f1-score   support
#
#            0       0.74      0.78      0.76      2433
#            1       0.89      0.80      0.84      6490
#            2       0.74      0.81      0.77      3024
#            3       0.83      0.87      0.85      3044
#            4       0.83      0.88      0.85      2232
#
#     accuracy                           0.82     17223
#    macro avg       0.81      0.83      0.82     17223
# weighted avg       0.83      0.82      0.82     17223
